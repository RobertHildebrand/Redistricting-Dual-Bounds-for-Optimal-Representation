# %% [markdown]
# # Main function
# Pick a config file and then run then main function on this config file.
#
# Alternatively, this can be run from the command line as
#
# python main.py config.json

# %%
# %load_ext autoreload
# %autoreload 2

import logging
logging.getLogger().setLevel(logging.ERROR)

import warnings; warnings.simplefilter('ignore')

# %%
from main import *


myConfig = "ExampleConfig-AL_step-max_bvap.json"
main(myConfig)
# Out:
# 2024-09-26 23:10:23,229 - INFO - Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2024-09-26 23:10:23,230 - INFO - NumExpr defaulting to 8 threads.
# /opt/anaconda3/envs/python377/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
# Reading config from ExampleConfig-AL_step-max_bvap.json
# Experiments to run:
# dict_keys(['AL_step-max_bvap_gradient_cuts_test'])
# In run AL_step-max_bvap_gradient_cuts_test using config: {'state': 'AL', 'level': 'county', 'base': 'labeling', 'obj': 'step-max', 'R': 45, 'dist_bounds': False, 'tlimit': 1, 'numGCuts': 0, 'timeGCuts': 10, 'fixing': False, 'contiguity': 'lcut', 'symmetry': 'none', 'extended': False, 'order': 'bvap', 'heuristic': True, 'lp': False, 'obj_order': False, 'index': 0}.
# data/county/dual_graphs/county01.json
#
# L = 645979 , U = 789529 , k = 7
# Set parameter Username
# 2024-09-26 23:10:24,102 - INFO - Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-26
# 2024-09-26 23:10:24,113 - INFO - Academic license - for non-commercial use only - expires 2025-09-26
# {'state': 'AL', 'level': 'county', 'base': 'labeling', 'obj': 'step-max', 'R': 45, 'dist_bounds': False, 'tlimit': 1, 'numGCuts': 0, 'timeGCuts': 10, 'fixing': False, 'contiguity': 'lcut', 'symmetry': 'none', 'extended': False, 'order': 'bvap', 'heuristic': True, 'lp': False, 'obj_order': False, 'index': 0, 'run': 'AL_step-max_bvap_gradient_cuts_test', 'k': 7, 'L': 645979, 'U': 789529, 'm': 171, 'n': 67, 'heur_obj': 'n/a', 'heur_time': 'n/a', 'heur_iter': 'n/a'}
# {'vap': {'lb': {'0': 492301.0, '1': 492290.0, '2': 492320.0, '3': 492720.0, '4': 494514.0, '5': 494805.0, '6': 498301.0}, 'ub': {'0': 628252.0, '1': 629083.0, '2': 629445.0, '3': 629465.0, '4': 629431.0, '5': 629395.0, '6': 627770.0}}, 'bvap': {'lb': {'0': 17991.000000000007, '1': 34852.0, '2': 46285.0, '3': 70675.00000000003, '4': 90318.0, '5': 119319.0, '6': 213751.00000000003}, 'ub': {'0': 127995.0, '1': 149996.0, '2': 174918.0, '3': 206778.87875849128, '4': 238406.0, '5': 265208.0, '6': 295634.0}}}
# {'vap': {'lb': {0: 492301.0, 1: 492290.0, 2: 492320.0, 3: 492720.0, 4: 494514.0, 5: 494805.0, 6: 498301.0}, 'ub': {0: 628252.0, 1: 629083.0, 2: 629445.0, 3: 629465.0, 4: 629431.0, 5: 629395.0, 6: 627770.0}}, 'bvap': {'lb': {0: 17991.000000000007, 1: 34852.0, 2: 46285.0, 3: 70675.00000000003, 4: 90318.0, 5: 119319.0, 6: 213751.00000000003}, 'ub': {0: 127995.0, 1: 149996.0, 2: 174918.0, 3: 206778.87875849128, 4: 238406.0, 5: 265208.0, 6: 295634.0}}}
# data/bestruns/AL-county-step-max-90.json
# Loading best known solution from data/bestruns/AL-county-step-max-90.json
# Loading best known solution from data/bestruns/AL-county-step-max-90.json
# Ordering warm start with respect to  bvap
# {5: 213751, 4: 183242, 1: 99793, 6: 227317, 2: 106597, 0: 30367, 3: 120656}
# {0: 527087, 1: 513654, 2: 554254, 3: 513255, 4: 602930, 5: 597136, 6: 608850}
# 1.586278295
# Set parameter LazyConstraints to value 1
# 2024-09-26 23:10:24,237 - INFO - Set parameter LazyConstraints to value 1
# Set parameter TimeLimit to value 1
# 2024-09-26 23:10:24,240 - INFO - Set parameter TimeLimit to value 1
# Set parameter Method to value 3
# 2024-09-26 23:10:24,240 - INFO - Set parameter Method to value 3
# Set parameter LogFile to value "../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45.log"
# 2024-09-26 23:10:24,243 - INFO - Set parameter LogFile to value "../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45.log"
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
# 2024-09-26 23:10:24,245 - INFO - Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
# 2024-09-26 23:10:24,246 - INFO -
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# 2024-09-26 23:10:24,247 - INFO - CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# 2024-09-26 23:10:24,249 - INFO - Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# 2024-09-26 23:10:24,250 - INFO -
# Optimize a model with 1054 rows, 1281 columns and 4599 nonzeros
# 2024-09-26 23:10:24,251 - INFO - Optimize a model with 1054 rows, 1281 columns and 4599 nonzeros
# Model fingerprint: 0x9a6b9e8b
# 2024-09-26 23:10:24,252 - INFO - Model fingerprint: 0x9a6b9e8b
# Variable types: 21 continuous, 1260 integer (1260 binary)
# 2024-09-26 23:10:24,254 - INFO - Variable types: 21 continuous, 1260 integer (1260 binary)
# Coefficient statistics:
# 2024-09-26 23:10:24,255 - INFO - Coefficient statistics:
#   Matrix range     [6e-03, 4e+06]
# 2024-09-26 23:10:24,256 - INFO -   Matrix range     [6e-03, 4e+06]
#   Objective range  [1e+00, 1e+00]
# 2024-09-26 23:10:24,257 - INFO -   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+05]
# 2024-09-26 23:10:24,259 - INFO -   Bounds range     [1e+00, 8e+05]
#   RHS range        [1e+00, 8e+05]
# 2024-09-26 23:10:24,260 - INFO -   RHS range        [1e+00, 8e+05]
# 2024-09-26 23:10:24,261 - INFO -
# Warning: Completing partial solution with 1193 unfixed non-continuous variables out of 1260
# 2024-09-26 23:10:24,262 - INFO - Warning: Completing partial solution with 1193 unfixed non-continuous variables out of 1260
# User MIP start produced solution with objective 1.69459 (0.02s)
# 2024-09-26 23:10:24,271 - INFO - User MIP start produced solution with objective 1.69459 (0.02s)
# Loaded user MIP start with objective 1.69459
# 2024-09-26 23:10:24,278 - INFO - Loaded user MIP start with objective 1.69459
# 2024-09-26 23:10:24,279 - INFO -
# Presolve removed 70 rows and 21 columns
# 2024-09-26 23:10:24,301 - INFO - Presolve removed 70 rows and 21 columns
# Presolve time: 0.02s
# 2024-09-26 23:10:24,303 - INFO - Presolve time: 0.02s
# Presolved: 984 rows, 1260 columns, 4431 nonzeros
# 2024-09-26 23:10:24,304 - INFO - Presolved: 984 rows, 1260 columns, 4431 nonzeros
# Variable types: 7 continuous, 1253 integer (1239 binary)
# 2024-09-26 23:10:24,312 - INFO - Variable types: 7 continuous, 1253 integer (1239 binary)
# Root relaxation presolved: 984 rows, 1260 columns, 4431 nonzeros
# 2024-09-26 23:10:24,315 - INFO - Root relaxation presolved: 984 rows, 1260 columns, 4431 nonzeros
# 2024-09-26 23:10:24,317 - INFO -
# 2024-09-26 23:10:24,319 - INFO -
# Use crossover to convert LP symmetric solution to basic solution...
# 2024-09-26 23:10:24,321 - INFO - Use crossover to convert LP symmetric solution to basic solution...
# 2024-09-26 23:10:24,325 - INFO -
# Root relaxation: objective 5.423006e+00, 651 iterations, 0.01 seconds (0.00 work units)
# 2024-09-26 23:10:24,327 - INFO - Root relaxation: objective 5.423006e+00, 651 iterations, 0.01 seconds (0.00 work units)
# 2024-09-26 23:10:24,375 - INFO -
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# 2024-09-26 23:10:24,376 - INFO -     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# 2024-09-26 23:10:24,378 - INFO -  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# 2024-09-26 23:10:24,379 - INFO -
#      0     0    5.42301    0  229    1.69459    5.42301   220%     -    0s
# 2024-09-26 23:10:24,380 - INFO -      0     0    5.42301    0  229    1.69459    5.42301   220%     -    0s
#      0     0    4.50233    0  279    1.69459    4.50233   166%     -    0s
# 2024-09-26 23:10:24,537 - INFO -      0     0    4.50233    0  279    1.69459    4.50233   166%     -    0s
#      0     0    4.49365    0  285    1.69459    4.49365   165%     -    0s
# 2024-09-26 23:10:24,564 - INFO -      0     0    4.49365    0  285    1.69459    4.49365   165%     -    0s
#      0     0    4.48651    0  284    1.69459    4.48651   165%     -    0s
# 2024-09-26 23:10:24,579 - INFO -      0     0    4.48651    0  284    1.69459    4.48651   165%     -    0s
#      0     0    4.48271    0  282    1.69459    4.48271   165%     -    0s
# 2024-09-26 23:10:24,595 - INFO -      0     0    4.48271    0  282    1.69459    4.48271   165%     -    0s
#      0     0    4.48062    0  283    1.69459    4.48062   164%     -    0s
# 2024-09-26 23:10:24,605 - INFO -      0     0    4.48062    0  283    1.69459    4.48062   164%     -    0s
#      0     0    4.47871    0  285    1.69459    4.47871   164%     -    0s
# 2024-09-26 23:10:24,616 - INFO -      0     0    4.47871    0  285    1.69459    4.47871   164%     -    0s
#      0     0    4.47500    0  284    1.69459    4.47500   164%     -    0s
# 2024-09-26 23:10:24,632 - INFO -      0     0    4.47500    0  284    1.69459    4.47500   164%     -    0s
#      0     0    4.47389    0  289    1.69459    4.47389   164%     -    0s
# 2024-09-26 23:10:24,638 - INFO -      0     0    4.47389    0  289    1.69459    4.47389   164%     -    0s
#      0     0    4.47131    0  286    1.69459    4.47131   164%     -    0s
# 2024-09-26 23:10:24,650 - INFO -      0     0    4.47131    0  286    1.69459    4.47131   164%     -    0s
#      0     0    4.47103    0  287    1.69459    4.47103   164%     -    0s
# 2024-09-26 23:10:24,666 - INFO -      0     0    4.47103    0  287    1.69459    4.47103   164%     -    0s
#      0     0    4.11544    0  276    1.69459    4.11544   143%     -    0s
# 2024-09-26 23:10:24,756 - INFO -      0     0    4.11544    0  276    1.69459    4.11544   143%     -    0s
#      0     0    4.04804    0  253    1.69459    4.04804   139%     -    0s
# 2024-09-26 23:10:24,785 - INFO -      0     0    4.04804    0  253    1.69459    4.04804   139%     -    0s
#      0     0    4.02415    0  277    1.69459    4.02415   137%     -    0s
# 2024-09-26 23:10:24,860 - INFO -      0     0    4.02415    0  277    1.69459    4.02415   137%     -    0s
#      0     0    4.01493    0  289    1.69459    4.01493   137%     -    0s
# 2024-09-26 23:10:24,879 - INFO -      0     0    4.01493    0  289    1.69459    4.01493   137%     -    0s
#      0     0    4.01023    0  292    1.69459    4.01023   137%     -    0s
# 2024-09-26 23:10:24,902 - INFO -      0     0    4.01023    0  292    1.69459    4.01023   137%     -    0s
#      0     0    4.00756    0  283    1.69459    4.00756   136%     -    0s
# 2024-09-26 23:10:24,911 - INFO -      0     0    4.00756    0  283    1.69459    4.00756   136%     -    0s
#      0     0    4.00671    0  287    1.69459    4.00671   136%     -    0s
# 2024-09-26 23:10:24,918 - INFO -      0     0    4.00671    0  287    1.69459    4.00671   136%     -    0s
#      0     0    4.00481    0  286    1.69459    4.00481   136%     -    0s
# 2024-09-26 23:10:24,923 - INFO -      0     0    4.00481    0  286    1.69459    4.00481   136%     -    0s
#      0     0    4.00376    0  283    1.69459    4.00376   136%     -    0s
# 2024-09-26 23:10:24,929 - INFO -      0     0    4.00376    0  283    1.69459    4.00376   136%     -    0s
#      0     0    4.00348    0  284    1.69459    4.00348   136%     -    0s
# 2024-09-26 23:10:24,935 - INFO -      0     0    4.00348    0  284    1.69459    4.00348   136%     -    0s
#      0     0    3.83394    0  283    1.69459    3.83394   126%     -    0s
# 2024-09-26 23:10:25,051 - INFO -      0     0    3.83394    0  283    1.69459    3.83394   126%     -    0s
#      0     0    3.81856    0  285    1.69459    3.81856   125%     -    0s
# 2024-09-26 23:10:25,078 - INFO -      0     0    3.81856    0  285    1.69459    3.81856   125%     -    0s
#      0     0    3.81148    0  287    1.69459    3.81148   125%     -    0s
# 2024-09-26 23:10:25,100 - INFO -      0     0    3.81148    0  287    1.69459    3.81148   125%     -    0s
#      0     0    3.81098    0  287    1.69459    3.81098   125%     -    0s
# 2024-09-26 23:10:25,107 - INFO -      0     0    3.81098    0  287    1.69459    3.81098   125%     -    0s
#      0     0    3.80816    0  287    1.69459    3.80816   125%     -    0s
# 2024-09-26 23:10:25,117 - INFO -      0     0    3.80816    0  287    1.69459    3.80816   125%     -    0s
#      0     0    3.80779    0  288    1.69459    3.80779   125%     -    0s
# 2024-09-26 23:10:25,122 - INFO -      0     0    3.80779    0  288    1.69459    3.80779   125%     -    0s
#      0     0    3.73924    0  278    1.69459    3.73924   121%     -    0s
# 2024-09-26 23:10:25,241 - INFO -      0     0    3.73924    0  278    1.69459    3.73924   121%     -    0s
#      0     0          -    0         1.69459    3.73924   121%     -    1s
# 2024-09-26 23:10:25,251 - INFO -      0     0          -    0         1.69459    3.73924   121%     -    1s
# 2024-09-26 23:10:25,252 - INFO -
# Cutting planes:
# 2024-09-26 23:10:25,253 - INFO - Cutting planes:
#   Implied bound: 19
# 2024-09-26 23:10:25,254 - INFO -   Implied bound: 19
#   MIR: 81
# 2024-09-26 23:10:25,255 - INFO -   MIR: 81
#   RLT: 12
# 2024-09-26 23:10:25,257 - INFO -   RLT: 12
#   Relax-and-lift: 67
# 2024-09-26 23:10:25,258 - INFO -   Relax-and-lift: 67
# 2024-09-26 23:10:25,259 - INFO -
# Explored 1 nodes (10697 simplex iterations) in 1.01 seconds (0.70 work units)
# 2024-09-26 23:10:25,260 - INFO - Explored 1 nodes (10697 simplex iterations) in 1.01 seconds (0.70 work units)
# Thread count was 12 (of 12 available processors)
# 2024-09-26 23:10:25,261 - INFO - Thread count was 12 (of 12 available processors)
# 2024-09-26 23:10:25,263 - INFO -
# Solution count 1: 1.69459
# 2024-09-26 23:10:25,264 - INFO - Solution count 1: 1.69459
# 2024-09-26 23:10:25,265 - INFO -
# Time limit reached
# 2024-09-26 23:10:25,266 - INFO - Time limit reached
# Best objective 1.694586061452e+00, best bound 3.739242108720e+00, gap 120.6581%
# 2024-09-26 23:10:25,267 - INFO - Best objective 1.694586061452e+00, best bound 3.739242108720e+00, gap 120.6581%
# 2024-09-26 23:10:25,268 - INFO -
# User-callback calls 496, time in user-callback 0.02 sec
# 2024-09-26 23:10:25,269 - INFO - User-callback calls 496, time in user-callback 0.02 sec
# ../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45
# Summarizing the results for export
# Results Summary started
# Warning: constraint name "vertex to district[0]" has a space
# 2024-09-26 23:10:25,271 - INFO - Warning: constraint name "vertex to district[0]" has a space
# Is this the error?
# Recording found solution
# best solution (found) = [[4, 15, 17, 19, 23, 34, 35, 38, 43, 47, 50, 52, 57, 59, 64, 66], [3, 12, 16, 49], [0, 14, 21, 24, 26, 27, 28, 32, 58, 62], [5, 6, 10, 18, 20, 29, 30, 31, 41, 48, 60], [2, 7, 9, 11, 13, 39, 40, 42, 46, 51, 55, 56, 61, 65], [22], [1, 8, 25, 33, 36, 37, 44, 45, 53, 54, 63]]
# print write mip soln
# ../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45.sol
# Exporting to json
# ../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45.json
# Exporting solution to json
# Summarizing ../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45.json
# ../results_for_ExampleConfig-AL_step-max_bvap/AL-county-step-max-45.json
# 2024-09-26 23:10:27,038 - ERROR - PROJ: internal_proj_identify: Cannot find proj.db
# 2024-09-26 23:10:27,040 - ERROR - PROJ: internal_proj_identify: Cannot find proj.db
# Plotting
# /opt/anaconda3/envs/python377/lib/python3.7/site-packages/geopandas/plotting.py:51: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:
# /opt/anaconda3/envs/python377/lib/python3.7/site-packages/geopandas/plotting.py:51: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if geom is not None and geom.type.startswith(prefix) and not geom.is_empty:
# The 'gradient_bounds' key does not exist in the result dictionary.
#
# Rest of the Result Dictionary:
# {'DFixings': 0,
#  'L': 645979,
#  'LFixings': 0,
#  'LP_obj': 'n/a',
#  'LP_time': 'n/a',
#  'MIP_bound': 3.739242108720247,
#  'MIP_nodes': 1,
#  'MIP_obj': 1.694586061451634,
#  'MIP_status': 9,
#  'MIP_time': '1.03',
#  'MIP_timelimit': 1,
#  'R': 45,
#  'U': 789529,
#  'UFixings_R': 0,
#  'UFixings_X': 0,
#  'ZFixings': 0,
#  'base': 'labeling',
#  'callbacks': 2,
#  'connected': True,
#  'contiguity': 'lcut',
#  'dist_bounds': False,
#  'extended': False,
#  'fixing': False,
#  'heur_iter': 'n/a',
#  'heur_obj': 'n/a',
#  'heur_time': 'n/a',
#  'heuristic': True,
#  'index': 0,
#  'k': 7,
#  'lazy_cuts': 0,
#  'level': 'county',
#  'lp': False,
#  'm': 171,
#  'n': 67,
#  'numGCuts': 0,
#  'obj': 'step-max',
#  'obj_order': False,
#  'order': 'bvap',
#  'run': 'AL_step-max_bvap_gradient_cuts_test',
#  'state': 'AL',
#  'symmetry': 'none',
#  'timeGCuts': 10,
#  'tlimit': 1}
# Adding to csv ../results_for_ExampleConfig-AL_step-max_bvap/results_ExampleConfig-AL_step-max_bvap_2024_Sep_26.csv
# func [0.006571555362570505, 0.055023265761839385, 0.0525973672719882, 0.0702018455669127, 0.3475739897615162, 0.47654217387938086, 0.5777680972970178]
# {'state': 'AL',
#  'level': 'county',
#  'base': 'labeling',
#  'obj': 'step-max',
#  'R': 45,
#  'dist_bounds': False,
#  'tlimit': 1,
#  'numGCuts': 0,
#  'timeGCuts': 10,
#  'fixing': False,
#  'contiguity': 'lcut',
#  'symmetry': 'none',
#  'extended': False,
#  'order': 'bvap',
#  'heuristic': True,
#  'lp': False,
#  'obj_order': False,
#  'index': 0,
#  'run': 'AL_step-max_bvap_gradient_cuts_test',
#  'k': 7,
#  'L': 645979,
#  'U': 789529,
#  'm': 171,
#  'n': 67,
#  'heur_obj': 'n/a',
#  'heur_time': 'n/a',
#  'heur_iter': 'n/a',
#  'DFixings': 0,
#  'UFixings_R': 0,
#  'LFixings': 0,
#  'UFixings_X': 0,
#  'ZFixings': 0,
#  'LP_obj': 'n/a',
#  'LP_time': 'n/a',
#  'MIP_timelimit': 1,
#  'MIP_time': '1.03',
#  'MIP_status': 9,
#  'MIP_nodes': 1,
#  'MIP_bound': 3.739242108720247,
#  'callbacks': 2,
#  'lazy_cuts': 0,
#  'MIP_obj': 1.694586061451634,
#  'connected': True}
