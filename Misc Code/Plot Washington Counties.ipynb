# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import json

# %%
washington_tract = gpd.read_file('tract/wa_pl2020_t_shp/wa_pl2020_t.shp')

# %%
washington_tract.plot(figsize = (20,10), edgecolor = 'black')
# Out:
# <AxesSubplot:>

# %%
washington_tract.plot(column = 'POP100',figsize = (20,10), legend = True)
# Out:
# <AxesSubplot:>

# %%
washington_bg.plot(column = 'POP100',figsize = (20,10), legend = True)
# Out:
# <AxesSubplot:>

# %%
len(washington_tract.index)
# Out:
# 1784

# %%
washington_bg = gpd.read_file('bg2020/wa_pl2020_bg_shp/wa_pl2020_bg.shp')

# %%
washington_bg.plot(figsize = (20,10), edgecolor = 'black')
# Out:
# <AxesSubplot:>

# %%
base = washington_bg.plot(figsize = (20,10), edgecolor = 'black', linewidth = 0.5)
washington_tract.boundary.plot(ax = base, color = 'white', linewidth = 0.5)
# Out:
# <AxesSubplot:>

# %%
len(washington_bg)
# Out:
# 5311

# %%
washington_b = pd.read_csv('block_csv/wa_pl2020_b_csv/wa_pl2020_b.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: DtypeWarning: Columns (29,31,35,37,38,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(washington_b)
# Out:
# 158093

# %%
washington = gpd.read_file('cnty/wa_pl2020_cnty_shp/wa_pl2020_cnty.shp')

# %%
len(washington)
# Out:
# 39

# %%
washington.plot(figsize=(15, 10), edgecolor = 'black')
# Out:
# <AxesSubplot:>

# %%
washington.plot(column='POP100', legend=True,figsize=(15, 10))
# Out:
# <AxesSubplot:>

# %%
# Opening JSON file
f = open('cnty/json/wa_pl2020_cnty.json',)
connections = json.load(f)

# %%
from gerrychain import Graph, Partition, Election, GeographicPartition

# %%
graph = Graph.from_json('cnty/json/wa_pl2020_cnty.json')

# %%
for edge in graph.edges:
    i = edge[0]
    j = edge[1]
    print(i)
    print(j)
    print([cities_geoid['INTPTLON20'][i],cities_geoid['INTPTLON20'][j]])
    print([cities_geoid['INTPTLAT20'][i], cities_geoid['INTPTLAT20'][j]])
    
    stop
# Out:
# 0500000US53051
# 0500000US53063
# ['-117.2321913', '-117.4033714']
# ['+48.5438247', '+47.6203752']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-0ca92ecc8b44> in <module>
#       7     print([cities_geoid['INTPTLAT20'][i], cities_geoid['INTPTLAT20'][j]])
#       8
# ----> 9     stop
#
# NameError: name 'stop' is not defined

# %%
connections.keys()
# Out:
# dict_keys(['directed', 'multigraph', 'graph', 'nodes', 'adjacency'])

# %%
connections['nodes']
# Out:
# [{'boundary_node': True,
#   'boundary_perim': 1.3515780270484967,
#   'area': 0.44955778914,
#   'STATEFP20': '53',
#   'COUNTYFP20': '051',
#   'COUNTYNS20': '01529157',
#   'GEOID20': '53051',
#   'NAME20': 'Pend Oreille',
#   'NAMELSAD20': 'Pend Oreille County',
#   'LSAD20': '06',
#   'CLASSFP20': 'H1',
#   'MTFCC20': 'G4020',
#   'CSAFP20': None,
#   'CBSAFP20': None,
#   'METDIVFP20': None,
#   'FUNCSTAT20': 'A',
#   'ALAND20': 3626617235,
#   'AWATER20': 65406812,
#   'INTPTLAT20': '+48.5438247',
#   'INTPTLON20': '-117.2321913',
#   'FILEID': 'PLST',
#   'STUSAB': 'WA',
#   'SUMLEV': '050',
#   'GEOVAR': '00',
#   'GEOCOMP': '00',
#   'CHARITER': '000',
#   'LOGRECNO': '0000027',
#   'GEOID': '0500000US53051',
#   'GEOCODE': '53051',
#   'REGION': '4',
#   'DIVISION': '9',
#   'STATE': '53',
#   'STATENS': '01779804',
#   'COUNTY': '051',
#   'COUNTYCC': 'H1',
#   'COUNTYNS': '01529157',
#   'CBSA': '99999',
#   'MEMI': '9',
#   'CSA': '999',
#   'METDIV': '99999',
# ...

# %%
connections['adjacency']
# Out:
# [[{'shared_perim': 0.39516031751718106, 'id': '0500000US53063'},
#   {'shared_perim': 1.3501613998426507, 'id': '0500000US53065'}],
#  [{'shared_perim': 0.7161502671851144, 'id': '0500000US53047'},
#   {'shared_perim': 1.9842949912354781, 'id': '0500000US53057'},
#   {'shared_perim': 0.3836456390118578, 'id': '0500000US53055'}],
#  [{'shared_perim': 1.3163092639462854, 'id': '0500000US53037'},
#   {'shared_perim': 0.31492442046002833, 'id': '0500000US53033'},
#   {'shared_perim': 1.2129034529911407, 'id': '0500000US53017'},
#   {'shared_perim': 1.035128928227859, 'id': '0500000US53061'},
#   {'shared_perim': 1.4908043109348308, 'id': '0500000US53047'},
#   {'shared_perim': 0.8213382579337328, 'id': '0500000US53057'}],
#  [{'shared_perim': 0.7181928663204253, 'id': '0500000US53023'},
#   {'shared_perim': 0.2333145937836405, 'id': '0500000US53075'}],
#  [{'shared_perim': 0.7063588338495672, 'id': '0500000US53043'},
#   {'shared_perim': 1.7274200202731653, 'id': '0500000US53065'},
# ...

# %%
s.plot()
    plt.plot([cities_geoid['INTPTLON20'][i],cities_geoid['INTPTLON20'][j]], [cities_geoid['INTPTLAT20'][i], cities_geoid['INTPTLAT20'][j]])

# %%
i
# Out:
# '0500000US53051'

# %%
Point(float(cities_geoid['INTPTLON20'][i]), float(cities_geoid['INTPTLAT20'][i]))

# %%
from shapely.geometry import LineString
for edge in graph.edges:
    i = edge[0]
    j = edge[1]
    A = Point(float(cities_geoid['INTPTLON20'][i]), float(cities_geoid['INTPTLAT20'][i]))
    B = Point(float(cities_geoid['INTPTLON20'][j]), float(cities_geoid['INTPTLAT20'][j]))
    AB = LineString([A,B])
    s = gpd.GeoSeries([AB])
    s.plot()
# Out:
# C:\Users\robert\AppData\Roaming\Python\Python38\site-packages\geopandas\plotting.py:384: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=figsize)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
base = washington.boundary.plot(ax = ax)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
cities.plot(ax=ax, marker='o', color='green', markersize=100)
base = washington.boundary.plot(ax = ax)

# %%
fig, ax = plt.subplots(figsize=(20, 10))
for edge in graph.edges:
    i = edge[0]
    j = edge[1]
    A = Point(float(cities_geoid['INTPTLON20'][i]), float(cities_geoid['INTPTLAT20'][i]))
    B = Point(float(cities_geoid['INTPTLON20'][j]), float(cities_geoid['INTPTLAT20'][j]))
    AB = LineString([A,B])
    s = gpd.GeoSeries([AB])
    s.plot(ax = ax, color = 'black')
cities.plot(ax=ax, color='green', markersize=100)



washington.boundary.plot(ax = ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20, 10))
for edge in graph.edges:
    i = edge[0]
    j = edge[1]
    A = Point(float(cities_geoid['INTPTLON20'][i]), float(cities_geoid['INTPTLAT20'][i]))
    B = Point(float(cities_geoid['INTPTLON20'][j]), float(cities_geoid['INTPTLAT20'][j]))
    AB = LineString([A,B])
    s = gpd.GeoSeries([AB])
    s.plot(ax = ax, color = 'black')
cities.plot(ax=ax, color='green', markersize=100)
# Out:
# <AxesSubplot:>

# %%
cities_geoid = cities.set_index('GEOID')

# %%
from shapely.geometry import Point
from shapely.geometry import LineString
AB = LineString([Point(1, 1), Point(2, 2)])
s = gpd.GeoSeries([AB])
s.plot()
# Out:
# <AxesSubplot:>

# %%
AB.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-9806b247f0d4> in <module>
# ----> 1 AB.plot()
#
# AttributeError: 'LineString' object has no attribute 'plot'

# %%
polygon_geom = Polygon(zip(['-117.2321913', '-117.4033714']
,['+48.5438247', '+47.6203752']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\speedups\_speedups.pyx in shapely.speedups._speedups.geos_linearring_from_py()
#
# AttributeError: 'zip' object has no attribute '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-af9ed10a81c5> in <module>
# ----> 1 polygon_geom = Polygon(zip(['-117.2321913', '-117.4033714']
#       2 ,['+48.5438247', '+47.6203752']))
#
# C:\ProgramData\Anaconda3\lib\site-packages\shapely\geometry\polygon.py in __init__(self, shell, holes)
#     241
#     242         if shell is not None:
# --> 243             ret = geos_polygon_from_py(shell, holes)
#     244             if ret is not None:
#     245                 self._geom, self._ndim = ret
#
# ...

# %%
cities
# Out:
#    STATEFP20 COUNTYFP20 COUNTYNS20 GEOID20        NAME20           NAMELSAD20  \
# 0         53        051   01529157   53051  Pend Oreille  Pend Oreille County
# 1         53        073   01529224   53073       Whatcom       Whatcom County
# 2         53        007   01531932   53007        Chelan        Chelan County
# 3         53        003   01533502   53003        Asotin        Asotin County
# 4         53        019   01531821   53019         Ferry         Ferry County
# 5         53        017   01531818   53017       Douglas       Douglas County
# 6         53        005   01513302   53005        Benton        Benton County
# 7         53        023   01533500   53023      Garfield      Garfield County
# 8         53        033   01531933   53033          King          King County
# 9         53        049   01513274   53049       Pacific       Pacific County
# 10        53        039   01529219   53039     Klickitat     Klickitat County
# ...

# %%
list(washington.keys())
# Out:
# ['STATEFP20',
#  'COUNTYFP20',
#  'COUNTYNS20',
#  'GEOID20',
#  'NAME20',
#  'NAMELSAD20',
#  'LSAD20',
#  'CLASSFP20',
#  'MTFCC20',
#  'CSAFP20',
#  'CBSAFP20',
#  'METDIVFP20',
#  'FUNCSTAT20',
#  'ALAND20',
#  'AWATER20',
#  'INTPTLAT20',
#  'INTPTLON20',
#  'FILEID',
#  'STUSAB',
#  'SUMLEV',
#  'GEOVAR',
#  'GEOCOMP',
#  'CHARITER',
#  'LOGRECNO',
#  'GEOID',
#  'GEOCODE',
#  'REGION',
#  'DIVISION',
#  'STATE',
#  'STATENS',
#  'COUNTY',
#  'COUNTYCC',
#  'COUNTYNS',
#  'CBSA',
#  'MEMI',
#  'CSA',
#  'METDIV',
#  'AREALAND',
#  'AREAWATR',
#  'BASENAME',
#  'NAME',
#  'FUNCSTAT',
#  'POP100',
#  'HU100',
#  'INTPTLAT',
#  'INTPTLON',
#  'LSADC',
#  'P0010001',
#  'P0010002',
#  'P0010003',
#  'P0010004',
#  'P0010005',
#  'P0010006',
#  'P0010007',
#  'P0010008',
#  'P0010009',
#  'P0010010',
#  'P0010011',
#  'P0010012',
#  'P0010013',
#  'P0010014',
#  'P0010015',
#  'P0010016',
#  'P0010017',
#  'P0010018',
#  'P0010019',
#  'P0010020',
#  'P0010021',
#  'P0010022',
# ...

# %%
cities = gpd.GeoDataFrame(washington, geometry=gpd.points_from_xy(washington.INTPTLON20, washington.INTPTLAT20))

# %%
fig, ax = plt.subplots(figsize = (15,15))
washington.boundary.plot(ax = ax)

# %%
cities.plot()
# Out:
# <AxesSubplot:>

# %%
cities = washington[['GEOID20', 'GEOID','INTPTLAT20','INTPTLON20' ]]

# %%
locations = [(washington['INTPTLAT20'][i], washington['INTPTLON20'][i]) for i in washington.index]

# %%
cities['geometry'] = locations
# Out:
# <ipython-input-19-db224014fa0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities['geometry'] = locations

# %%
cities.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9790492f9578> in <module>
# ----> 1 cities.plot()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
? cities
